# %%
import pandas as pd

# %%
a = {'students' : ['david','samuel','terry','evan'],'age':['27','24','22','32'],
     'country':['uk','canada','chine','usa'],
     'course':['python','data structure','machine learning','web development'],
    'marks':['85','72','89','76']}

# %%
df = pd.DataFrame(a)

# %%
b=df[['marks']]
b
# Out:
#   marks
# 0    85
# 1    72
# 2    89
# 3    76

# %%
c=df[['country','course']]
c
# Out:
#   country            course
# 0      uk            python
# 1  canada    data structure
# 2   chine  machine learning
# 3     usa   web development

# %%
df[['students']]
# Out:
#   students
# 0    david
# 1   samuel
# 2    terry
# 3     evan

# %% [markdown]
# loc[row_lable,column_lable], iloc[row_index, column_index]
# slicing loc[row,column] u can use index and coumn name or lable both in single brace "[]" using "loc" or "iloc" function

# %% [markdown]
# Day 2

# %%
# %pip install xlrd openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv"
df = pd.read_csv(filename)

# %%
df.head()
# Out:
#    OrderID     Product     Category  Quantity  Price  Total   OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600  2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800  2022-02-15
# 2        3  Desk Chair    Furniture         5    150    750  2022-03-12
# 3        4    Notebook   Stationery        10      2     20  2022-04-05
# 4        5     Monitor  Electronics         1    300    300  2022-05-21
#
#   CustomerCity
# 0     New York
# 1  Los Angeles
# 2      Chicago
# 3      Houston
# 4        Miami

# %%
q=df[['Price']]
q
# Out:
#    Price
# 0    800
# 1    600
# 2    150
# 3      2
# 4    300

# %%
q=df[["Product","Category"]]
q
# Out:
#       Product     Category
# 0      Laptop  Electronics
# 1  Smartphone  Electronics
# 2  Desk Chair    Furniture
# 3    Notebook   Stationery
# 4     Monitor  Electronics

# %%
df.iloc[1,2]
# Out:
# 'Electronics'

# %%
new_index=['a','b','c','d','e']
df_new = df
df_new.index = new_index
df_new.loc['a','CustomerCity']
df_new.loc['a':'b','CustomerCity']
# Out:
# a       New York
# b    Los Angeles
# Name: CustomerCity, dtype: str
